# %% [markdown]
# <a href="https://colab.research.google.com/github/Andywrites/Content-Writing/blob/main/Stock_Market_Price_on_Industrial_Output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %%
x = np.array([3, 3.2, 3.4, 4, 4.6, 5.1, 5.7, 6.2, 7.720107344, 8.799976791, 17.65039683, 24.89338638, 23.06197053, 18.90275532, 4.951065083, 8.9, 10.4, 2.497462112, 14.7, 11.68635014, 12.66233964, 13.76801349, 30.50899275, 14.15777535, 10.92286182, 13.77321651, 9.416535754, 12.11394677, 15.49841183, 10.93139639, 10.13613901, 7.362536524, 9.905001389, 7.473943432, 9.256055405, 13.08865554, 13.08865554, 14, 14.6, 15.2])
y = np.array([17.73635842, 21.05450311, 21.009999, 18.78351295, 21.0196417, 18.35403221, 17.78259534, 19.49458715, 17.65449303, 18.37625, 20.92708023, 19.99371557, 19.10108021, 19.19853144, 17.45056588, 16.25736913, 13.93340041, 13.9253596, 11.81181308, 12.06060684, 10.86156992, 10.06108332, 8.852872608, 8.401379657, 8.168912972, 7.838411937, 6.552816976, 7.171084296, 7.724546672, 8.928929322, 9.635811603, 9.428437322, 8.679697782, 8.741993492, 9.648947481, 11.5223587, 12.66726516, 14.61070297, 13.59351333, 14.61])

# %%
degree = 1

# %%
coeffs = np.polyfit(x, y, degree)

# %%
y_fit = np.polyval(coeffs, x)

# %%
corr_matrix = np.corrcoef(y, y_fit)

# %%
r_squared = corr_matrix[0, 1]**2

# %%
import scipy.stats as stats

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

# %%
result = stats.linregress(x, y)
plt.xlabel('Stock Price', fontweight='bold')
plt.ylabel('Industrial Output', fontweight='bold')
plt.scatter(x, y), plt.plot(x, result.intercept + result.slope*x,'r')
plt.title("Industrial Output on Stock Market Price", fontsize=10, fontweight='bold')
plt.suptitle("Slope = -0.1639x, Intercept = 15.67, R² = 0.0440, p-value = 0.1937, std.error = 0.1238, Y t-value = 0.194, X t-value = 0.000", fontsize=6.5, x=0.5, y=0.99, fontweight='bold')
plt.savefig('plot.png', dpi=900)
plt.show()

# %%
4.40/100
# Out:
# 0.044000000000000004
